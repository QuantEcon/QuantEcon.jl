# %% [markdown]
# # quant-econ Solutions: Infinite Horizon Dynamic Programming
#
# Solutions for http://quant-econ.net/dp_intro.html

# %%
using QuantEcon
using PyPlot
# Out:
# INFO: Loading help data...

# %% [markdown]
# ## Exercise 1

# %%
alpha, bet = 0.65, 0.95
gm = GrowthModel() 
true_sigma = (1 - alpha*bet) .* [gm.grid].^alpha
w = 5 .* gm.u([gm.grid]) .- 25  # Initial condition

fig, ax = plt.subplots(3, 1)

bellman(w) = bellman_operator(gm, w)

for (i, n) in enumerate((2, 4, 6))
    ax[i][:set_ylim](0, 1)
    ax[i][:set_xlim](0, 2)
    ax[i][:set_yticks]((0, 1))
    ax[i][:set_xticks]((0, 2))

    v_star = compute_fixed_point(bellman, w, max_iter=n)
    sigma = compute_greedy(gm, v_star)

    ax[i][:plot](gm.grid, sigma, "b-", lw=2, alpha=0.8, label="approximate optimal policy")
    ax[i][:plot](gm.grid, true_sigma, "k-", lw=2, alpha=0.8, label="true optimal policy")
    ax[i][:legend](loc="upper left")
    ax[i][:set_title]("$n value function iterations")
end
# Out:
# Compute iterate 1 with error 4.284179229018932
# Compute iterate 2 with error 4.069970266613851
# Compute iterate 1 with error 4.284179229018932
# Compute iterate 2 with error 4.069970266613851
# Compute iterate 3 with error 3.8664717525523997
# Compute iterate 4 with error 3.6731481643337673
# Compute iterate 1 with error 4.284179229018932
# Compute iterate 2 with error 4.069970266613851
# Compute iterate 3 with error 3.8664717525523997
# Compute iterate 4 with error 3.6731481643337673
# Compute iterate 5 with error 3.489490755617183
# Compute iterate 6 with error 3.315016217399176
# Figure(PyObject <matplotlib.figure.Figure object at 0x11a0b9a10>)

# %% [markdown]
# ## Exercise 2

# %%
import Grid: CoordInterpGrid, BCnan, InterpLinear

gm = GrowthModel()
w = 5 .* gm.u(gm.grid) .- 25

discount_factors = [0.9, 0.94, 0.98]
series_length = 25

fig, ax = subplots()

ax[:set_xlabel]("time")
ax[:set_ylabel]("capital")

for bet in discount_factors

    # Compute the optimal policy given the discount factor
    gm.β = bet
    bellman(w) = bellman_operator(gm, w)
    v_star = compute_fixed_point(bellman, w, max_iter=20)
    sigma = compute_greedy(gm, v_star)
    
    # Compute the corresponding time series for capital
    k = Array(Float64, series_length)
    k[1] = 0.1
    
    sigma_func = CoordInterpGrid(gm.grid, sigma, BCnan, InterpLinear)
    
    for t=2:series_length
        k[t] = gm.f(k[t-1]) - sigma_func[k[t-1]]
    end
    ax[:plot](1:series_length, k, "o-", lw=2, alpha=0.75, 
              label=LaTeXString("\$\\beta =$(bet)\$"))
    
end

ax[:legend](loc="lower right");
# Out:
# Compute iterate 1 with error 5.999395781311421
# Compute iterate 2 with error 3.791226346877096
# Compute iterate 3 with error 2.531866455281204
# Compute iterate 4 with error 1.7670233130921105
# Compute iterate 5 with error 1.3030657774797803
# Compute iterate 6 with error 1.0111672424675398
# Compute iterate 7 with error 0.8161968633637926
# Compute iterate 8 with error 0.6891992010282522
# Compute iterate 9 with error 0.5902972954685204
# Compute iterate 10 with error 0.5142011777274043
# Compute iterate 11 with error 0.4545869407154335
# Compute iterate 12 with error 0.4026200186131703
# Compute iterate 13 with error 0.3591150352441126
# Compute iterate 14 with error 0.32171465885994266
# Compute iterate 15 with error 0.2882976406379534
# Compute iterate 16 with error 0.2583597332817007
# Compute iterate 17 with error 0.23215045031339088
# Compute iterate 18 with error 0.20878598156182093
# Compute iterate 19 with error 0.18783794747113802
# Compute iterate 20 with error 0.16902220976486504
# Compute iterate 1 with error 4.401009614208945
# Compute iterate 2 with error 3.1427994782252284
# Compute iterate 3 with error 2.954231508878209
# Compute iterate 4 with error 2.7769776178331966
# Compute iterate 5 with error 2.610358960342026
# Compute iterate 6 with error 2.4537374223621526
# Compute iterate 7 with error 2.3065131767036746
# Compute iterate 8 with error 2.1681223858171705
# Compute iterate 9 with error 2.038035042408822
# Compute iterate 10 with error 1.91575293962471
# Compute iterate 11 with error 1.8008077630247357
# Compute iterate 12 with error 1.6927592970358631
# Compute iterate 13 with error 1.5911937390196726
# Compute iterate 14 with error 1.4957221144967576
# Compute iterate 15 with error 1.4059787866465996
# Compute iterate 16 with error 1.321620059193279
# Compute iterate 17 with error 1.242322854474338
# Compute iterate 18 with error 1.1677834838575052
# Compute iterate 19 with error 1.09771647596898
# Compute iterate 20 with error 1.031853486015109
# Compute iterate 1 with error 7.1065058125407745
# Compute iterate 2 with error 6.9643756951126505
# Compute iterate 3 with error 6.825088180230466
# Compute iterate 4 with error 6.688586415771596
# Compute iterate 5 with error 6.55481468668394
# Compute iterate 6 with error 6.42371839223506
# Compute iterate 7 with error 6.29524402416294
# Compute iterate 8 with error 6.169339142723118
# Compute iterate 9 with error 6.045952359424007
# Compute iterate 10 with error 5.925033311018979
# Compute iterate 11 with error 5.806347200775548
# Compute iterate 12 with error 5.688476392427191
# Compute iterate 13 with error 5.5713449071035654
# Compute iterate 14 with error 5.45516899090336
# Compute iterate 15 with error 5.3401252412529345
# Compute iterate 16 with error 5.22635599629163
# Compute iterate 17 with error 5.113980700560518
# Compute iterate 18 with error 5.003098782811122
# Compute iterate 19 with error 4.893789590139221
# Compute iterate 20 with error 4.786117832445569
# Figure(PyObject <matplotlib.figure.Figure object at 0x11d4c8550>)
